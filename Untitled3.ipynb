# %% [markdown]
# Q 1) Define the z-statistic and explain its relationship to the standard normal distribution. How is the
# z-statistic used in hypothesis testing?

# %% [markdown]
# Ans) The z-statistic, or z-score, is a measure that describes how many standard deviations a data point (or sample statistic) is away from the population mean. It is calculated using the formula:
#
# 𝑧
# =
# 𝑋
# −
# 𝜇
# 𝜎
# z=
# σ
# X−μ
# ​
#
# where:
#
# 𝑋
# X is the value or sample mean,
# 𝜇
# μ is the population mean,
# 𝜎
# σ is the standard deviation of the population.
# The z-statistic is closely related to the standard normal distribution, which is a normal distribution with a mean of 0 and a standard deviation of 1. When a z-score is calculated, it effectively "standardizes" a data point from any normal distribution, allowing comparisons against this standard normal distribution.
#
# Relationship to the Standard Normal Distribution:
# The z-statistic represents the position of a value in terms of how many standard deviations it lies away from the mean.
# For a standard normal distribution:
# A z-score of 0 corresponds to the mean.
# A positive z-score indicates the value is above the mean.
# A negative z-score indicates the value is below the mean.
# A z-score of 1, 2, or 3 indicates the value is 1, 2, or 3 standard deviations from the mean, respectively.
# Z-statistic in Hypothesis Testing:
# In hypothesis testing, the z-statistic is used to determine how far a sample mean deviates from a hypothesized population mean. This is done under the assumption that the sampling distribution of the test statistic is normally distributed (or approximately normal, by the Central Limit Theorem for large samples).
#
# The process involves the following steps:
#
# Null Hypothesis (
# 𝐻
# 0
# H
# 0
# ​
#  ): Typically, this asserts that there is no effect or no difference (e.g.,
# 𝜇
# =
# 𝜇
# 0
# μ=μ
# 0
# ​
#  ).
#
# Alternative Hypothesis (
# 𝐻
# 𝑎
# H
# a
# ​
#  ): This proposes that there is a significant effect or difference (e.g.,
# 𝜇
# ≠
# 𝜇
# 0
# μ
# 
# =μ
# 0
# ​
#  ).
#
# Calculate the z-statistic using the formula for the sample mean:
#
# 𝑧
# =
# 𝑋
# ˉ
# −
# 𝜇
# 0
# 𝜎
# 𝑛
# z=
# n
# ​
#
# σ
# ​
#
# X
# ˉ
#  −μ
# 0
# ​
#
# ​
#
# where:
#
# 𝑋
# ˉ
# X
# ˉ
#   is the sample mean,
# 𝜇
# 0
# μ
# 0
# ​
#   is the hypothesized population mean,
# 𝜎
# σ is the population standard deviation (or sample standard deviation for large samples),
# 𝑛
# n is the sample size.
# Determine the p-value: The z-score is compared to a standard normal distribution to find the p-value, which indicates the probability of observing a test statistic as extreme as the z-score under the null hypothesis.
#
# Decision: Based on the p-value and a predefined significance level (
# 𝛼
# α, such as 0.05), the null hypothesis is either rejected or not rejected. If the p-value is less than
# 𝛼
# α, the null hypothesis is rejected, suggesting that the sample provides enough evidence to support the alternative hypothesis.
#
# Example:
# If a researcher wants to test whether the average height of a population differs from a hypothesized mean of 170 cm, and the sample data gives a z-score of 2.1, they would compare this z-score to the critical values of the standard normal distribution (usually
# 𝑧
# =
# 1.96
# z=1.96 for a two-tailed test at
# 𝛼
# =
# 0.05
# α=0.05). If the z-score falls beyond these critical values, the null hypothesis is rejected.
#
# In summary, the z-statistic standardizes observations to allow comparisons with the standard normal distribution, and in hypothesis testing, it helps determine whether the sample mean is significantly different from the population mean.

# %% [markdown]
# Q2)  What is a p-value, and how is it used in hypothesis testing? What does it mean if the p-value is
# very small (e.g., 0.01)?

# %% [markdown]
# Ans) A p-value is the probability of obtaining a test statistic (e.g., z-score) as extreme as, or more extreme than, the one observed, assuming the null hypothesis (
# 𝐻
# 0
# H
# 0
# ​
#  ) is true. It quantifies the evidence against the null hypothesis in hypothesis testing.
#
# Interpretation of p-value:
# A small p-value suggests that the observed data is unlikely under the null hypothesis.
# A large p-value suggests that the observed data is likely under the null hypothesis.
# In hypothesis testing, the p-value is compared to a predefined significance level (
# 𝛼
# α), which is typically set at 0.05 (or 5%). The decision rule is:
#
# If
# p-value
# ≤
# 𝛼
# p-value≤α, reject the null hypothesis (
# 𝐻
# 0
# H
# 0
# ​
#  ). This indicates that the data provides strong evidence against the null hypothesis, and it is likely that the alternative hypothesis (
# 𝐻
# 𝑎
# H
# a
# ​
#  ) is true.
# If
# p-value
# >
# 𝛼
# p-value>α, fail to reject the null hypothesis. This means the data is consistent with the null hypothesis, and there is insufficient evidence to support the alternative hypothesis.
# What does a small p-value (e.g., 0.01) mean?
# A small p-value, such as 0.01, indicates that there is only a 1% probability of observing a test statistic as extreme as the one obtained if the null hypothesis were true. In other words, the data strongly contradicts the null hypothesis.
#
# If the p-value is very small, it means that the observed effect is highly unlikely to have occurred by random chance under the assumption that the null hypothesis is correct.
#
# Example:
# Suppose a researcher is testing whether a new drug is more effective than a placebo. The null hypothesis (
# 𝐻
# 0
# H
# 0
# ​
#  ) might be that the drug has no effect, while the alternative hypothesis (
# 𝐻
# 𝑎
# H
# a
# ​
#  ) is that the drug does have an effect. If the p-value comes out to be 0.01, this suggests that there is only a 1% chance of observing the current difference in effectiveness between the drug and the placebo if the drug truly had no effect. Therefore, the researcher would reject the null hypothesis and conclude that the drug likely has a significant effect.
# Key Points:
# A p-value does not directly measure the probability that the null hypothesis is true or false.
# A very small p-value (e.g., 0.01) suggests strong evidence against the null hypothesis.
# However, a small p-value alone does not indicate the size of the effect, only that the observed effect is statistically significant.
# In practice, setting a threshold for statistical significance (e.g.,
# 𝛼
# =
# 0.05
# α=0.05) helps to control the likelihood of making a Type I error (incorrectly rejecting the null hypothesis).

# %% [markdown]
# Q 3) Compare and contrast the binomial and Bernoulli distributions.

# %% [markdown]
# The Binomial and Bernoulli distributions are both discrete probability distributions that describe the outcomes of experiments with two possible outcomes, typically referred to as "success" and "failure." However, they differ in terms of the scope and application.
#
# 1. Bernoulli Distribution
# The Bernoulli distribution models a single trial with two possible outcomes:
#
# Success (with probability
# 𝑝
# p).
# Failure (with probability
# 1
# −
# 𝑝
# 1−p).
# Key characteristics:
# Random variable (X): Takes only two values, typically:
#
# 𝑋
# =
# 1
# X=1 (success) with probability
# 𝑝
# p,
# 𝑋
# =
# 0
# X=0 (failure) with probability
# 1
# −
# 𝑝
# 1−p.
# 𝑃
# (
# 𝑋
# =
# 1
# )
# =
# 𝑝
# ,
# 𝑃
# (
# 𝑋
# =
# 0
# )
# =
# 1
# −
# 𝑝
# P(X=1)=p,P(X=0)=1−p
# Mean (expected value):
#
# 𝐸
# (
# 𝑋
# )
# =
# 𝑝
# E(X)=p
# Variance:
#
# Var
# (
# 𝑋
# )
# =
# 𝑝
# (
# 1
# −
# 𝑝
# )
# Var(X)=p(1−p)
# Application: The Bernoulli distribution describes a single binary (yes/no, success/failure) event or trial, such as flipping a coin once, where "heads" is success and "tails" is failure.
#
# 2. Binomial Distribution
# The Binomial distribution models the number of successes in a fixed number of independent Bernoulli trials, where each trial has the same probability of success
# 𝑝
# p. In other words, the binomial distribution sums the outcomes of multiple Bernoulli trials.
#
# Key characteristics:
# Random variable (X): Represents the number of successes in
# 𝑛
# n independent trials, where each trial is a Bernoulli process with probability
# 𝑝
# p.
#
# 𝑃
# (
# 𝑋
# =
# 𝑘
# )
# =
# (
# 𝑛
# 𝑘
# )
# 𝑝
# 𝑘
# (
# 1
# −
# 𝑝
# )
# 𝑛
# −
# 𝑘
# P(X=k)=(
# k
# n
# ​
#  )p
# k
#  (1−p)
# n−k
#
# where:
#
# 𝑘
# k is the number of successes (
# 𝑘
# =
# 0
# ,
# 1
# ,
# 2
# ,
# …
# ,
# 𝑛
# k=0,1,2,…,n),
# (
# 𝑛
# 𝑘
# )
# (
# k
# n
# ​
#  ) is the binomial coefficient representing the number of ways to choose
# 𝑘
# k successes from
# 𝑛
# n trials.
# Mean (expected value):
#
# 𝐸
# (
# 𝑋
# )
# =
# 𝑛
# 𝑝
# E(X)=np
# Variance:
#
# Var
# (
# 𝑋
# )
# =
# 𝑛
# 𝑝
# (
# 1
# −
# 𝑝
# )
# Var(X)=np(1−p)
# Application: The binomial distribution is used for experiments involving multiple independent Bernoulli trials. For example, it describes the probability of getting exactly 5 heads in 10 flips of a fair coin.
#
# Key Relationships:
# The Bernoulli distribution is a special case of the Binomial distribution with
# 𝑛
# =
# 1
# n=1. That is, a Binomial distribution with one trial is a Bernoulli distribution.
# If you perform multiple independent Bernoulli trials and count the number of successes, the outcome follows a Binomial distribution.
#
# Example:
# Bernoulli trial: Flipping a coin once where "heads" is success (
# 𝑝
# =
# 0.5
# p=0.5).
# Binomial experiment: Flipping a coin 10 times and counting the number of heads, which follows a binomial distribution with parameters
# 𝑛
# =
# 10
# n=10 and
# 𝑝
# =
# 0.5
# p=0.5.

# %% [markdown]
# Q 4) : Under what conditions is the binomial distribution used, and how does it relate to the Bernoulli
# distribution

# %% [markdown]
# Ans) The binomial distribution is used under specific conditions that involve a sequence of independent, identical trials with only two possible outcomes (commonly referred to as "success" and "failure"). These conditions ensure that the probability model accurately reflects a series of such trials.
#
# Conditions for Using the Binomial Distribution:
# Fixed number of trials (n):
#
# The number of trials,
# 𝑛
# n, is fixed in advance. Each trial is an independent event.
# Two possible outcomes per trial:
#
# Each trial can result in only two possible outcomes: success or failure. These outcomes are often coded as 1 (success) and 0 (failure).
# Constant probability of success (p):
#
# The probability of success,
# 𝑝
# p, is the same for each trial. Similarly, the probability of failure is
# 1
# −
# 𝑝
# 1−p.
# Independent trials:
#
# The outcome of one trial does not affect the outcome of any other trial. Each trial is independent of the others.
# If these conditions are satisfied, the binomial distribution can be used to model the number of successes in
# 𝑛
# n trials.
#
# Binomial Distribution Formula:
# For a binomial distribution, the probability of obtaining exactly
# 𝑘
# k successes in
# 𝑛
# n trials, where each trial has a probability
# 𝑝
# p of success, is given by the formula:
#
# 𝑃
# (
# 𝑋
# =
# 𝑘
# )
# =
# (
# 𝑛
# 𝑘
# )
# 𝑝
# 𝑘
# (
# 1
# −
# 𝑝
# )
# 𝑛
# −
# 𝑘
# P(X=k)=(
# k
# n
# ​
#  )p
# k
#  (1−p)
# n−k
#
# where:
#
# 𝑋
# X is the random variable representing the number of successes,
# 𝑘
# k is the number of successes (
# 0
# ≤
# 𝑘
# ≤
# 𝑛
# 0≤k≤n),
# (
# 𝑛
# 𝑘
# )
# (
# k
# n
# ​
#  ) is the binomial coefficient, which represents the number of ways to choose
# 𝑘
# k successes from
# 𝑛
# n trials,
# 𝑝
# p is the probability of success on each trial.
# Relation to the Bernoulli Distribution:
# The Bernoulli distribution is a special case of the binomial distribution when the number of trials
# 𝑛
# =
# 1
# n=1. In other words, the binomial distribution generalizes the Bernoulli distribution to multiple independent trials.
#
# Key Connections:
# Bernoulli distribution: Describes a single trial where the probability of success is
# 𝑝
# p and the probability of failure is
# 1
# −
# 𝑝
# 1−p.
#
# If
# 𝑋
# X is a random variable following a Bernoulli distribution, the probability mass function (PMF) is:
# 𝑃
# (
# 𝑋
# =
# 1
# )
# =
# 𝑝
# ,
# 𝑃
# (
# 𝑋
# =
# 0
# )
# =
# 1
# −
# 𝑝
# P(X=1)=p,P(X=0)=1−p
# Binomial distribution: Describes the number of successes in
# 𝑛
# n independent Bernoulli trials, each with the same probability
# 𝑝
# p. If you perform multiple Bernoulli trials and count the number of successes, the outcome follows a binomial distribution.
#
# The binomial distribution is essentially the sum of
# 𝑛
# n independent Bernoulli random variables. If
# 𝑋
# 1
# ,
# 𝑋
# 2
# ,
# …
# ,
# 𝑋
# 𝑛
# X
# 1
# ​
#  ,X
# 2
# ​
#  ,…,X
# n
# ​
#   are independent Bernoulli random variables with success probability
# 𝑝
# p, then the sum
# 𝑋
# =
# 𝑋
# 1
# +
# 𝑋
# 2
# +
# ⋯
# +
# 𝑋
# 𝑛
# X=X
# 1
# ​
#  +X
# 2
# ​
#  +⋯+X
# n
# ​
#   follows a binomial distribution with parameters
# 𝑛
# n and
# 𝑝
# p.
#
# Summary of the Relationship:
# The Bernoulli distribution models a single trial (a single "success" or "failure").
# The Binomial distribution models the total number of successes in a fixed number of independent Bernoulli trials.
# If
# 𝑛
# =
# 1
# n=1, the binomial distribution is the same as the Bernoulli distribution. Thus, the Bernoulli distribution is a special case of the binomial distribution for
# 𝑛
# =
# 1
# n=1.

# %% [markdown]
# Q5 )  What are the key properties of the Poisson distribution, and when is it appropriate to use this
# distribution?

# %% [markdown]
# ANS )The Poisson distribution is a discrete probability distribution that models the number of occurrences of a particular event within a fixed interval of time, space, or any other unit of measure (such as area, volume, etc.), given that the events occur with a constant rate and independently of each other.
#
# Key Properties of the Poisson Distribution:
#
# Discrete random variable:
#
# The Poisson distribution models the number of events (
# 𝑋
# X) occurring in a fixed interval, where
# 𝑋
# X is a non-negative integer (i.e.,
# 𝑋
# =
# 0
# ,
# 1
# ,
# 2
# ,
# 3
# ,
# …
# X=0,1,2,3,…).
#
# Mean and variance:
#
# Both the mean and the variance of the Poisson distribution are equal to the rate parameter
# 𝜆
# λ. That is:
# 𝐸
# (
# 𝑋
# )
# =
# 𝜆
# ,
# Var
# (
# 𝑋
# )
# =
# 𝜆
# E(X)=λ,Var(X)=λ
# where
# 𝜆
# λ is the average number of occurrences in the interval.
#
#
# Probability mass function (PMF):
#
# The probability of observing exactly
# 𝑘
# k events in a given interval is given by the formula:
# 𝑃
# (
# 𝑋
# =
# 𝑘
# )
# =
# 𝜆
# 𝑘
# 𝑒
# −
# 𝜆
# 𝑘
# !
# ,
# 𝑘
# =
# 0
# ,
# 1
# ,
# 2
# ,
# …
# P(X=k)=
# k!
# λ
# k
#  e
# −λ
#
# ​
#  ,k=0,1,2,…
# where:
#
# 𝜆
# λ is the average number of events per interval,
# 𝑒
# e is Euler's number (approximately 2.71828),
# 𝑘
# !
# k! is the factorial of
# 𝑘
# k.
#
# Memoryless property:
#
# The Poisson distribution has a memoryless property when dealing with occurrences over time. This means that the probability of an event occurring in the next time interval is independent of how much time has already passed without an event occurring.
#
# Independence of events:
#
# The events occur independently of each other. The occurrence of one event does not affect the probability of another event occurring.
#
# Non-overlapping intervals:
#
# If you consider two disjoint or non-overlapping intervals, the number of events in these intervals is independent of each other. This makes it useful for modeling events in different time periods or regions.
#
# Rare events model:
#
# The Poisson distribution is often used to model rare or infrequent events, especially when the number of possible occurrences is large, but the actual occurrences are few.
# When is the Poisson Distribution Appropriate?:
# The Poisson distribution is appropriate when the following conditions are met:
#
# Events occur randomly: The events are scattered randomly and independently within the interval of interest.
#
# Constant rate (
# 𝜆
# λ): The average rate at which events occur (denoted by
# 𝜆
# λ) is constant throughout the interval. This means the expected number of occurrences in any fixed interval is proportional to the length of that interval.
#
# Independence of events: The occurrences of events are independent of each other. The occurrence of one event does not influence the occurrence of another.
#
# Rare events: The events are relatively rare, and the probability of more than one event occurring in an infinitesimally small sub-interval is negligible.
#
# Examples of Use Cases:
# The Poisson distribution is commonly used in various real-world situations where we count occurrences over time, space, or other units. Some common examples include:
#
# Number of phone calls received by a call center per hour: Assuming calls arrive randomly and independently.
#
# Number of accidents at an intersection per day: If the occurrence of accidents follows a random process.
#
# Number of emails received in an hour: Under the assumption that emails arrive independently at a constant average rate.
#
# Number of defects in a length of wire: If the defects are distributed randomly along the length.
#
# Number of goals scored in a soccer match: Assuming goals are relatively rare and independent events.
#
# Relation to Other Distributions:
#
# The Poisson distribution can be viewed as the limiting case of the binomial distribution when the number of trials
# 𝑛
# n is large, and the probability of success
# 𝑝
# p is small, but the product
# 𝑛
# 𝑝
# np (i.e., the expected number of successes) remains constant. Specifically, if
# 𝑋
# X follows a binomial distribution
# Bin
# (
# 𝑛
# ,
# 𝑝
# )
# Bin(n,p) and
# 𝑛
# →
# ∞
# n→∞ while
# 𝑝
# →
# 0
# p→0, such that
# 𝜆
# =
# 𝑛
# 𝑝
# λ=np, then
# 𝑋
# X will converge to a Poisson distribution with mean
# 𝜆
# λ.
#
#
# In summary, the Poisson distribution is used when we are counting the number of occurrences of an event over a fixed interval of time or space, and these events occur randomly and independently at a constant average rate.

# %% [markdown]
# Q 6)Define the terms "probability distribution" and "probability density function" (PDF). How does a
# PDF differ from a probability mass function (PMF)?

# %% [markdown]
# Ans) Probability Distribution:
# A probability distribution describes how the probability of a random variable is distributed over its possible values. It provides the likelihood of different outcomes for a random variable in a given situation. There are two main types of probability distributions, based on whether the random variable is discrete or continuous:
#
# Discrete probability distribution: Deals with random variables that take on a finite or countable set of values. The probability of each specific outcome is given.
#
# Continuous probability distribution: Deals with random variables that can take on an infinite number of values within a range, typically described using a probability density function (PDF).
#
# In short, a probability distribution tells us the likelihood of each possible value that a random variable can assume, either as exact values (for discrete variables) or within a range (for continuous variables).
#
# Probability Density Function (PDF):
#
# A probability density function (PDF) is used to describe the probability distribution of a continuous random variable. Unlike the probability of discrete outcomes, the probability of a continuous variable taking on any specific value is zero. Instead, the PDF helps determine the probability that the variable falls within a certain range.
#
# The PDF, denoted as
# 𝑓
# (
# 𝑥
# )
# f(x), describes the relative likelihood of the random variable
# 𝑋
# X taking a value near
# 𝑥
# x. The probability that
# 𝑋
# X falls within an interval
# [
# 𝑎
# ,
# 𝑏
# ]
# [a,b] is given by the area under the curve of the PDF between
# 𝑎
# a and
# 𝑏
# b, which is calculated as the integral of the PDF over that range:
# 𝑃
# (
# 𝑎
# ≤
# 𝑋
# ≤
# 𝑏
# )
# =
# ∫
# 𝑎
# 𝑏
# 𝑓
# (
# 𝑥
# )
#
# 𝑑
# 𝑥
# P(a≤X≤b)=∫
# a
# b
# ​
#  f(x)dx
#
# Properties of a PDF:
#
# Non-negative:
# 𝑓
# (
# 𝑥
# )
# ≥
# 0
# f(x)≥0 for all
# 𝑥
# x.
#
# Total area under the curve equals 1: The integral of the PDF over the entire range of possible values is 1, ensuring that the total probability is 100%.
# ∫
# −
# ∞
# ∞
# 𝑓
# (
# 𝑥
# )
#
# 𝑑
# 𝑥
# =
# 1
# ∫
# −∞
# ∞
# ​
#  f(x)dx=1
#
#
# Probability Mass Function (PMF):
#
# A probability mass function (PMF) is used to describe the probability distribution of a discrete random variable. It assigns a probability to each specific value that the random variable can take.
#
# The PMF, denoted as
# 𝑃
# (
# 𝑋
# =
# 𝑥
# )
# P(X=x), gives the probability that a discrete random variable
# 𝑋
# X takes a specific value
# 𝑥
# x. In other words, it lists the probability of each possible outcome of the random variable.
#
# Properties of a PMF:
#
# Non-negative:
# 𝑃
# (
# 𝑋
# =
# 𝑥
# )
# ≥
# 0
# P(X=x)≥0 for all values
# 𝑥
# x.
#
# Total sum equals 1: The sum of the probabilities of all possible values must be 1:
# ∑
# 𝑥
# 𝑃
# (
# 𝑋
# =
# 𝑥
# )
# =
# 1
# x
# ∑
# ​
#  P(X=x)=1
#
#
# Difference between PDF and PMF:
#
# Type of Random Variable:
#
# PMF is used for discrete random variables (e.g., the number of heads in coin flips, number of goals in a soccer game).
# PDF is used for continuous random variables (e.g., height, temperature, time).
#
#
# Probability at a Specific Value:
#
# For a PMF, you can calculate the probability of the random variable being exactly equal to a specific value (e.g.,
# 𝑃
# (
# 𝑋
# =
# 2
# )
# P(X=2) could be 0.3).
# For a PDF, the probability of the random variable being exactly equal to any specific value is 0. Instead, the probability is calculated over an interval (e.g., the probability that
# 𝑋
# X lies between 2 and 3).
#
# Summation vs. Integration:
#
# In a PMF, probabilities are summed over the discrete outcomes.
# In a PDF, probabilities are found by integrating the function over a continuous range of outcomes.
#
#
# Summary:
# A probability distribution shows how probabilities are distributed across values of a random variable.
# A PMF describes the probability distribution for discrete variables by assigning probabilities to each distinct outcome.
# A PDF describes the probability distribution for continuous variables by assigning probabilities over intervals, and the probability is found by integrating over the desired range.

# %% [markdown]
# Q 7)  Explain the Central Limit Theorem (CLT) with example.

# %% [markdown]
# Ans) The Central Limit Theorem (CLT) is a fundamental theorem in statistics that states that the sampling distribution of the sample mean (or sum) of a large enough number of independent, identically distributed random variables will be approximately normal (i.e., follow a normal distribution), regardless of the original distribution of the population. This approximation holds as long as the sample size is sufficiently large.
#
# In simple terms, the CLT tells us that when we take many samples of a certain size from any population (whether it's normally distributed or not), the distribution of the sample means will tend to form a normal (bell-shaped) curve as the sample size increases.
#
# Key Components of the Central Limit Theorem:
#
# Sample size: The sample size needs to be large enough (typically
# 𝑛
# ≥
# 30
# n≥30 is considered sufficient) for the theorem to hold true.
#
# Independence: The sampled observations must be independent of each other.
# Identically distributed: The samples should come from the same population, meaning that they are identically distributed.
#
# Mean and variance:
# The mean of the sampling distribution of the sample means will be the same as the mean of the population.
#
# The variance of the sampling distribution of the sample means will be the population variance divided by the sample size (
# 𝑛
# n).
# Mathematically, if
# 𝑋
# 1
# ,
# 𝑋
# 2
# ,
# …
# ,
# 𝑋
# 𝑛
# X
# 1
# ​
#  ,X
# 2
# ​
#  ,…,X
# n
# ​
#   are independent, identically distributed random variables with mean
# 𝜇
# μ and variance
# 𝜎
# 2
# σ
# 2
#  , then the sample mean
# 𝑋
# ˉ
# X
# ˉ
#   for a large
# 𝑛
# n is approximately normally distributed:
#
# 𝑋
# ˉ
# ∼
# 𝑁
# (
# 𝜇
# ,
# 𝜎
# 2
# 𝑛
# )
# X
# ˉ
#  ∼N(μ,
# n
# σ
# 2
#
# ​
#  )
# This approximation becomes more accurate as
# 𝑛
# n increases.
#
#
# Why is the Central Limit Theorem Important?
#
# Inference: The CLT allows us to make inferences about the population mean using the sample mean, even if the population is not normally distributed.
#
# Hypothesis testing and confidence intervals: The CLT is essential for performing hypothesis tests and constructing confidence intervals for population means when the population distribution is unknown or not normal.
#
# Example of the Central Limit Theorem:
#
# Suppose you are studying the amount of time people spend on a website in a given day. The distribution of time spent on the site is highly skewed to the right (many people spend only a few minutes, but a few spend hours). Let's assume the population mean is
# 𝜇
# =
# 10
# μ=10 minutes with a population standard deviation
# 𝜎
# =
# 8
# σ=8 minutes.
#
# Now, take repeated random samples of size
# 𝑛
# =
# 50
# n=50 (sample sizes above 30 are generally sufficient) and calculate the sample mean for each sample.
#
#
# Original population: The individual times spent on the website follow a highly skewed distribution, not normal at all.
#
# Distribution of sample means: According to the CLT, the distribution of the sample means (for samples of size 50) will be approximately normal with:
# Mean
# 𝜇
# 𝑋
# ˉ
# =
# 10
# μ
# X
# ˉ
#
# ​
#  =10 minutes (same as the population mean),
# Standard deviation (standard error of the mean)
# 𝜎
# 𝑋
# ˉ
# =
# 8
# 50
# =
# 1.13
# σ
# X
# ˉ
#
# ​
#  =
# 50
# ​
#
# 8
# ​
#  =1.13 minutes.
# So, even though the original distribution is not normal, the distribution of the sample means for sufficiently large
# 𝑛
# n will approximate a normal distribution.
#
# Visualization Example:
#
# Population distribution: Highly skewed to the right.
# Sample means distribution (for
# 𝑛
# =
# 50
# n=50): Bell-shaped and approximately normal.
#
# This allows you to apply normal probability techniques (e.g., confidence intervals and hypothesis testing) to the sample means, regardless of the skewness or non-normality of the original population distribution.
#
#
# Summary:
#
# The Central Limit Theorem is crucial in statistics because it justifies the use of the normal distribution as an approximation for the distribution of sample means (or sums) when dealing with large samples, even when the original data does not follow a normal distribution. It provides a foundation for many statistical methods and applications.

# %% [markdown]
#  Q 8)  Compare z-scores and t-scores. When should you use a z-score, and when should a t-score applied instead ?

# %% [markdown]
# Ans ) Z-scores and T-scores (or T-statistics) are both measures used in hypothesis testing and confidence intervals to standardize individual data points or sample statistics. However, they are used in different contexts depending on the availability of information about the population and sample size. Let’s break down their differences and when to use each.
#
# Z-Scores (Z-statistics):
# A z-score measures how many standard deviations a data point or sample mean is from the population mean. It assumes that the population follows a normal distribution and that the population's standard deviation is known.
#
# Formula for Z-score:
# For a single data point:
#
# 𝑍
# =
# 𝑋
# −
# 𝜇
# 𝜎
# Z=
# σ
# X−μ
# ​
#
# For a sample mean:
#
# 𝑍
# =
# 𝑋
# ˉ
# −
# 𝜇
# 𝜎
# 𝑛
# Z=
# n
# ​
#
# σ
# ​
#
# X
# ˉ
#  −μ
# ​
#
# Where:
#
# 𝑋
# X = individual data point,
# 𝑋
# ˉ
# X
# ˉ
#   = sample mean,
# 𝜇
# μ = population mean,
# 𝜎
# σ = population standard deviation,
# 𝑛
# n = sample size.
# When to Use a Z-Score:
# Population standard deviation (
# 𝜎
# σ) is known: Z-scores are used when the population standard deviation is known or when you have a large enough sample that the sample standard deviation is a good approximation of the population standard deviation.
#
# Sample size is large (
# 𝑛
# ≥
# 30
# n≥30): With large sample sizes, the sample mean will tend to be normally distributed, even if the population distribution is not, due to the Central Limit Theorem (CLT). In these cases, the Z-distribution is appropriate.
#
# Normal distribution: If the population is normally distributed, z-scores can be used even for smaller sample sizes.
#
# T-Scores (T-statistics):
# A t-score is used when the population standard deviation is unknown, and it must be estimated from the sample data. The t-distribution is similar to the normal distribution but has heavier tails, which accounts for the added uncertainty in using the sample standard deviation.
#
# Formula for T-score:
# 𝑇
# =
# 𝑋
# ˉ
# −
# 𝜇
# 𝑠
# 𝑛
# T=
# n
# ​
#
# s
# ​
#
# X
# ˉ
#  −μ
# ​
#
# Where:
#
# 𝑋
# ˉ
# X
# ˉ
#   = sample mean,
# 𝜇
# μ = population mean,
# 𝑠
# s = sample standard deviation (used to estimate
# 𝜎
# σ),
# 𝑛
# n = sample size.
# When to Use a T-Score:
# Population standard deviation (
# 𝜎
# σ) is unknown: If you don’t know the population standard deviation and must estimate it using the sample standard deviation, the t-distribution is more appropriate than the z-distribution.
#
# Sample size is small (
# 𝑛
# <
# 30
# n<30): The t-distribution is especially important when you have a small sample size, as the sampling distribution of the sample mean is more spread out (heavier tails) than the normal distribution. As the sample size increases, the t-distribution approaches the normal distribution.
#
# Estimating the population mean: When conducting hypothesis tests or constructing confidence intervals for the population mean and the standard deviation is unknown, you should use the t-distribution.
#
# Key Differences Between Z-Scores and T-Scores:
# Characteristic	Z-Score	T-Score
# Population Standard Deviation (
# 𝜎
# σ)	Known or assumed to be known	Unknown, estimated from sample
# Sample Size	Typically large (
# 𝑛
# ≥
# 30
# n≥30)	Typically small (
# 𝑛
# <
# 30
# n<30)
# Distribution	Standard Normal Distribution (Z-distribution)	T-distribution (heavier tails)
# Application	Hypothesis testing and confidence intervals when
# 𝜎
# σ is known	Hypothesis testing and confidence intervals when
# 𝜎
# σ is unknown
# Shape of Distribution	Symmetrical, bell-shaped, thinner tails	Symmetrical, bell-shaped, heavier tails
# Practical Example:
# Using a Z-Score: Suppose you want to test whether the average height of adult males in a population is 70 inches. You know the population standard deviation (
# 𝜎
# =
# 3
# σ=3 inches). You take a random sample of 40 individuals and calculate a sample mean of 69 inches. Since the population standard deviation is known and the sample size is large, you would use the z-score.
#
# 𝑍
# =
# 69
# −
# 70
# 3
# 40
# =
# −
# 2.11
# Z=
# 40
# ​
#
# 3
# ​
#
# 69−70
# ​
#  =−2.11
# Using a T-Score: Suppose now that you don’t know the population standard deviation. Instead, you take a sample of 20 individuals and calculate a sample mean of 69 inches and a sample standard deviation of
# 𝑠
# =
# 3
# s=3 inches. Since the population standard deviation is unknown and the sample size is small, you would use the t-score.
#
# 𝑇
# =
# 69
# −
# 70
# 3
# 20
# =
# −
# 1.49
# T=
# 20
# ​
#
# 3
# ​
#
# 69−70
# ​
#  =−1.49
# In this case, you would refer to a t-distribution table with
# 𝑛
# −
# 1
# =
# 19
# n−1=19 degrees of freedom to interpret the result.
#
# Summary:
# Use a z-score when the population standard deviation is known and the sample size is large (typically
# 𝑛
# ≥
# 30
# n≥30).
# Use a t-score when the population standard deviation is unknown, especially if the sample size is small (typically
# 𝑛
# <
# 30
# n<30).
# As the sample size increases, the t-distribution converges to the z-distribution, and for very large samples, the z-score and t-score become almost identical.

# %% [markdown]
# Q 9) Given a sample mean of 105, a population mean of 100, a standard deviation of 15, and a sample
# size of 25, calculate the z-score and p-value. Based on a significance level of 0.05, do you reject or fail to
# reject the null hypothesis?
#
#  Task: Write Python code to calculate the z-score and p-value for the given data.
#
# Objective: Apply the formula for the z-score and interpret the p-value for hypothesis testing.

# %%
import scipy.stats as stats

# Given values
sample_mean = 105
population_mean = 100
standard_deviation = 15
sample_size = 25

# Calculate the z-score
z_score = (sample_mean - population_mean) / (standard_deviation / (sample_size ** 0.5))

# Calculate the p-value (two-tailed test)
p_value = 2 * (1 - stats.norm.cdf(abs(z_score)))

# Output the results
z_score, p_value
# Out:
# (1.6666666666666667, 0.09558070454562939)

# %% [markdown]
# ans The calculated z-score is approximately 1.67, and the p-value is approximately 0.096.
#
# Decision:
# The significance level (α) is 0.05.
# Since the p-value (0.096) is greater than the significance level (0.05),
#  we fail to reject the null hypothesis.
#
# Conclusion:
# There is insufficient evidence to conclude that the sample mean is significantly different from the population mean at the 0.05 significance level. ​

# %% [markdown]
# Q10) Simulate a binomial distribution with 10 trials and a probability of success of 0.6 using Python.
# Generate 1,000 samples and plot the distribution. What is the expected mean and variance?
#
# Task: Use Python to generate the data, plot the distribution, and calculate the mean and variance.
#
# Objective: Understand the properties of a binomial distribution and verify them through simulation.

# %% [markdown]
# Ans ) ![image.png](data:image/png;base64,...)

# %% [markdown]
# he expected mean of the binomial distribution is 6.0, and the expected variance is 2.4.
#
# # The plot above shows the distribution of 1,000 samples generated from a binomial distribution with 10 trials and a probability of success of 0.6. The distribution is centered around the mean of 6, which is consistent with the theoretical expectation

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parameters for the binomial distribution
n_trials = 10
p_success = 0.6
n_samples = 1000

# Generate 1000 samples from a binomial distribution
samples = np.random.binomial(n_trials, p_success, n_samples)

# Calculate the expected mean and variance
mean = n_trials * p_success
variance = n_trials * p_success * (1 - p_success)

# Plot the distribution of the samples
plt.hist(samples, bins=np.arange(0, n_trials + 2) - 0.5, edgecolor='black', density=True)
plt.title('Binomial Distribution (n=10, p=0.6, 1000 samples)')
plt.xlabel('Number of successes')
plt.ylabel('Frequency')
plt.grid(True)
plt.show()

mean, variance
# Out:
# (6.0, 2.4000000000000004)
